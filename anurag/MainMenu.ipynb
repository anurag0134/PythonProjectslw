# %%
import os

# %%
import subprocess

# %%
"""
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Please say something")
    recognizer.adjust_for_ambient_noise(source)
    audio = recognizer.listen(source)
    
    try:
        s = recognizer.recognize_sphinx(audio)
        print("You said: " + s)
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Error; {0}".format(e))
"""
# Out:
# '\nimport speech_recognition as sr\n\nrecognizer = sr.Recognizer()\n\nwith sr.Microphone() as source:\n    print("Please say something")\n    recognizer.adjust_for_ambient_noise(source)\n    audio = recognizer.listen(source)\n    \n    try:\n        s = recognizer.recognize_sphinx(audio)\n        print("You said: " + s)\n    except sr.UnknownValueError:\n        print("Could not understand audio")\n    except sr.RequestError as e:\n        print("Error; {0}".format(e))\n'

# %%
import speech_recognition as sr
import pyttsx3
import subprocess

# Initialize the text-to-speech engine
engine = pyttsx3.init()

"""
# Define the paths to your applications
apps = {
    "notepad": "notepad.exe",
    "calculator": "calc.exe",
    "microsoft edge": "C:\\Program Files (x86)\\Microsoft\\Edge\\Application\\msedge.exe",
    "visual studio code": "C:\\Users\\YourUsername\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe",
    "spotify": "C:\\Users\\Aditya Singh\\AppData\\Roaming\\Spotify\\Spotify.exe",
    "search": "F:\\WebDev\\16_05_24.html"
    # Add more apps as needed
}
"""

def speak(text):
    engine.say(text)
    engine.runAndWait()

def recognize_speech():
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()
    
    with microphone as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
    
    try:
        command = recognizer.recognize_google(audio)
        print(f"You said: {command}")
        return command.lower()
    except sr.UnknownValueError:
        speak("Sorry, I did not understand that.")
        return None
    except sr.RequestError:
        speak("Sorry, there was a problem with the speech recognition service.")
        return None
    """

def open_app(app_name):
    app_path = apps.get(app_name.lower())
    if app_path:
        try:
            os.startfile(app_path)
            subprocess.Popen(app_path)
            speak(f"Opening {app_name}")
        except FileNotFoundError:
            speak(f"Application not found: {app_name}")
    else:
        speak(f"Application not recognized: {app_name}")
"""
def main():
        speak("Hello, I am ready to open applications for you. Please say a command.")
    #while True:
        command = recognize_speech()
        if command:
            #if "open" in command:
            if 'notepad' in command : #1
                os.system("notepad")
            elif 'chrome' in command:
                subprocess.run("C:\Program Files\Google\Chrome\Application\chrome.exe")
            elif 'search' in command:
                os.startfile("F:/WebDev/16_05_24.html")
            elif 'image using html' in command:
                os.startfile("F:/WebDev/Capture_Image.html")
            elif 'details' in command:
                os.startfile("F:/WebDev/task1_19_05_24.html")
            elif 'interpreter' in command:
                os.startfile("F:/WebDev/task3_19_05_24.html")
            elif 'volume' in command:
                os.system("python F:\WebDev\changeVolume.py")
            elif 'stream' in command:
                os.system("python F:\WebDev\Open_camera.py")
            elif 'image' in command:
                os.system("F:\WebDev\photo.py")
            elif 'query' in command:
                os.system("start chrome https://forms.gle/78TBEGctTQxFbfNZA")
            elif 'audio' in command:
                os.system("python F:\WebDev\audiototext.py")
            elif 'top' in command:
                os.system("python F:\WebDev\top5results.py")
            elif 'location' in command:
                os.syaytem("python F:\WebDev\findlocation.py")

                #app_name = command.replace("open", "").strip()
                #open_app(app_name)
            elif command in ["quit", "exit", "close"]:
                speak("Goodbye!")
                #break
            else:
                speak("Please say 'open' followed by the application name.")

if __name__ == "__main__":
    main()
# Out:
#   File <tokenize>:60
#     while True:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
"""
command= input("enter string: ")
if 'notepad' in command : #1
    os.system("notepad")
elif 'chrome' in command:
    subprocess.run("C:\Program Files\Google\Chrome\Application\chrome.exe")
elif 'search' in command:
    os.startfile("F:/WebDev/16_05_24.html")
elif 'image using html' in command:
    os.startfile("F:/WebDev/Capture_Image.html")
elif 'form' in command:
    os.startfile("F:/WebDev/task1_19_05_24.html")
elif 'html interpreter' in command:
    os.startfile("F:/WebDev/task3_19_05_24.html")
elif 'volume' in command:
    os.system("python F:\WebDev\changeVolume.py")
elif 'stream' in command:
    os.system("python F:\WebDev\Open_camera.py")
elif 'image using python' in command:
    os.system("F:\WebDev\photo.py")
elif 'query' in command:
    os.system("start chrome https://forms.gle/78TBEGctTQxFbfNZA")

"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #command= input("enter string: ")
# ----> 2 if 'notepad' in command : #1
#       3     os.system("notepad")
#       4 elif 'chrome' in command:
#
# NameError: name 'command' is not defined

# %%
while True:
    command = recognize_speech()
    if command:
            #if "open" in command:
    if 'notepad' in command : #1
        os.system("notepad")
    elif 'chrome' in command:
                subprocess.run("C:\Program Files\Google\Chrome\Application\chrome.exe")
            elif 'search' in command:
                os.startfile("F:/WebDev/16_05_24.html")
            elif 'image using html' in command:
                os.startfile("F:/WebDev/Capture_Image.html")
            elif 'details' in command:
                os.startfile("F:/WebDev/task1_19_05_24.html")
            elif 'interpreter' in command:
                os.startfile("F:/WebDev/task3_19_05_24.html")
            elif 'volume' in command:
                os.system("python F:\WebDev\changeVolume.py")
            elif 'stream' in command:
                os.system("python F:\WebDev\Open_camera.py")
            elif 'image' in command:
                os.system("F:\WebDev\photo.py")
            elif 'query' in command:
                os.system("start chrome https://forms.gle/78TBEGctTQxFbfNZA")
            elif 'audio' in command:
                os.system("python F:\WebDev\audiototext.py")
            elif 'top' in command:
                os.system("python F:\WebDev\top5results.py")
            elif 'location' in command:
                os.syaytem("python F:\WebDev\findlocation.py")

                #app_name = command.replace("open", "").strip()
                #open_app(app_name)
            elif command in ["quit", "exit", "close"]:
                speak("Goodbye!")
                #break
            else:
                speak("Please say 'open' followed by the application name.")

if __name__ == "__main__":
    main()
